# %%
import sys
sys.path.append('E:\sklearn\\')
import KNN

# %%
group,labels=KNN.createDataSet()
group
# Out:
# array([[1. , 1.1],
#        [1. , 1. ],
#        [0. , 0. ],
#        [0. , 0.1]])

# %%
labels
# Out:
# ['A', 'A', 'B', 'B']

# %%
KNN.classify0([1.0,1.0],group,labels,3)
# Out:
# 'A'

# %%
datingDataMat,datingDataLabels=KNN.file2matrix('datingTestSet2.txt')

# %%
import matplotlib
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111)
ax.scatter(datingDataMat[:,1],datingDataMat[:,2])
plt.show()

# %%
#利用datingDataLabels存储类标签属性，通过scatter函数个性化标记点
from numpy import *
import matplotlib
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111)
ax.scatter(datingDataMat[:,1],datingDataMat[:,2],15.0*array(datingDataLabels),15.0*array(datingDataLabels))
plt.show()

# %%
normMat,ranges,minVals=KNN.autoNorm(datingDataMat)
normMat
# Out:
# array([[0.44832535, 0.39805139, 0.56233353],
#        [0.15873259, 0.34195467, 0.98724416],
#        [0.28542943, 0.06892523, 0.47449629],
#        ...,
#        [0.29115949, 0.50910294, 0.51079493],
#        [0.52711097, 0.43665451, 0.4290048 ],
#        [0.47940793, 0.3768091 , 0.78571804]])

# %%
ranges
# Out:
# array([9.1273000e+04, 2.0919349e+01, 1.6943610e+00])

# %%
minVals
# Out:
# array([0.      , 0.      , 0.001156])

# %%
#海伦约会分类结果
KNN.datingClassTest()
# Out:
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 3
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 3, the real answer is 3
# the classifier came back with: 2, the real answer is 2
# the classifier came back with: 1, the real answer is 1
# the classifier came back with: 3, the real answer is 1
# the total error rate is 0.050000

# %%
KNN.classifyPerson()
# Out:
# You will probably like this person: in small doses

# %%
#testVector=KNN.img2vector('E:\sklearn\\testDigits\\0_13.txt')

# %%
KNN.handwritingClassTest()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e9aac823daf8> in <module>
# ----> 1 KNN.handwritingClassTest()
#
# e:\sklearn\KNN.py in handwritingClassTest()
#      92 def handwritingClassTest():
#      93     hwLabels = []
# ---> 94     trainingFileList = listdir('testDigits')           #load the training set
#      95     m = len(trainingFileList)
#      96     trainingMat = zeros((m,1024))
#
# NameError: name 'listdir' is not defined

# %%
testVector
